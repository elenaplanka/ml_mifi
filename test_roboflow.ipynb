# %%
from roboflow import Roboflow


rf = Roboflow(api_key="oW12nmstypouYsTfXrjv")
project = rf.workspace().project("ssg-ig3qc")
model = project.version(4).model

# infer on a local image
print(model.predict("rob_test.jpg").json())

# infer on an image hosted elsewhere
#print(model.predict("valid/110_jpg.rf.165968ca010be007126d5a5b2d848f85.jpg").json())

# save an image annotated with your predictions
model.predict("rob_test.jpg").save("prediction.jpg")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# {'predictions': [{'segmentation_mask': '...', 'class_map': {'0': 'background', '1': 'Agriculture', '2': 'Barenland', '3': 'Forest', '4': 'Rangeland', '5': 'Road', '6': 'Unknown', '7': 'Water', '8': 'urban'}, 'image': {'width': 4080, 'height': 3072}, 'image_path': 'rob_test.jpg', 'prediction_type': 'SemanticSegmentationModel'}], 'image': {'width': '4080', 'height': '3072'}}
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 15
#       9 print(model.predict("rob_test.jpg").json())
#      11 # infer on an image hosted elsewhere
#      12 #print(model.predict("valid/110_jpg.rf.165968ca010be007126d5a5b2d848f85.jpg").json())
#      13
#      14 # save an image annotated with your predictions
# ---> 15 model.predict("rob_test.jpg").save("prediction.jpg")
#
# ...
